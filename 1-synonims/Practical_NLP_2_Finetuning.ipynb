# %% [markdown]
# <a href="https://colab.research.google.com/github/axel-sirota/practical-nlp/blob/main/1-synonims/Practical_NLP_2_Finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Oct 13 17:42:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (1.2.0)

# %%
import multiprocessing
import tensorflow as tf
import sys
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, Embedding, Lambda
from keras.utils import np_utils
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from textblob import TextBlob, Word
from keras_preprocessing.sequence import pad_sequences
from keras.initializers import Constant
import numpy as np
import random
import os
import pandas as pd
import gensim
import warnings
import nltk

TRACE = False
embedding_dim = 100
epochs=2
batch_size = 500
BATCH = True

def set_seeds_and_trace():
  os.environ['PYTHONHASHSEED'] = '0'
  np.random.seed(42)
  tf.random.set_seed(42)
  random.seed(42)
  if TRACE:
    tf.debugging.set_log_device_placement(True)

def set_session_with_gpus_and_cores():
  cores = multiprocessing.cpu_count()
  gpus = len(tf.config.list_physical_devices('GPU'))
  config = tf.compat.v1.ConfigProto( device_count = {'GPU': gpus  , 'CPU': cores} , intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
  sess = tf.compat.v1.Session(config=config) 
  K.set_session(sess)

set_seeds_and_trace()
set_session_with_gpus_and_cores()
warnings.filterwarnings('ignore')
nltk.download('punkt')
tokenizer = lambda x: TextBlob(x).words
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# %%writefile get_data.sh
# if [ ! -f yelp.csv ]; then
#   wget -O yelp.csv https://www.dropbox.com/s/xds4lua69b7okw8/yelp.csv?dl=0
# fi
#
# if [ ! -f glove.6B.100d.txt ]; then
#   wget -O glove.6B.100d.txt https://www.dropbox.com/s/dl1vswq2sz5f1ws/glove.6B.100d.txt?dl=0
# fi
# Out:
# Writing get_data.sh

# %%
# !bash get_data.sh
# Out:
# --2022-10-13 17:42:59--  https://www.dropbox.com/s/xds4lua69b7okw8/yelp.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/xds4lua69b7okw8/yelp.csv [following]
# --2022-10-13 17:42:59--  https://www.dropbox.com/s/raw/xds4lua69b7okw8/yelp.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc165ad61e2069d6eccc096f14f1.dl.dropboxusercontent.com/cd/0/inline/BuxyjeiJrE64HslhF316G3i0TpfpaDj9tTUY5TbUzB5LO4lFqqTFpdWGNhRfBSbkZqiLfShIJIa73vZK7H0_L9AHyIio8IQZBuJgNUJSoPHJBUz1SMU-lh0Pz_3qeR-chgeha0s5fhiKGRplzpQHG68vwwm9B55-RvWqmDWiGE6bCA/file# [following]
# --2022-10-13 17:43:00--  https://uc165ad61e2069d6eccc096f14f1.dl.dropboxusercontent.com/cd/0/inline/BuxyjeiJrE64HslhF316G3i0TpfpaDj9tTUY5TbUzB5LO4lFqqTFpdWGNhRfBSbkZqiLfShIJIa73vZK7H0_L9AHyIio8IQZBuJgNUJSoPHJBUz1SMU-lh0Pz_3qeR-chgeha0s5fhiKGRplzpQHG68vwwm9B55-RvWqmDWiGE6bCA/file
# Resolving uc165ad61e2069d6eccc096f14f1.dl.dropboxusercontent.com (uc165ad61e2069d6eccc096f14f1.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc165ad61e2069d6eccc096f14f1.dl.dropboxusercontent.com (uc165ad61e2069d6eccc096f14f1.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8091185 (7.7M) [text/plain]
# Saving to: ‘yelp.csv’
#
# yelp.csv            100%[===================>]   7.72M  --.-KB/s    in 0.06s
#
# 2022-10-13 17:43:00 (124 MB/s) - ‘yelp.csv’ saved [8091185/8091185]
#
# --2022-10-13 17:43:00--  https://www.dropbox.com/s/dl1vswq2sz5f1ws/glove.6B.100d.txt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/dl1vswq2sz5f1ws/glove.6B.100d.txt [following]
# --2022-10-13 17:43:00--  https://www.dropbox.com/s/raw/dl1vswq2sz5f1ws/glove.6B.100d.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd3dada479b364e64135989358a.dl.dropboxusercontent.com/cd/0/inline/BuzfYkLFm6ehKK6rmKt2mqApbkICJZKTVM1sUktzv-PHYTpPyNXHmPo3CbpOHI-QROu90sGHiZHYZM3X7fhb510XKLJUWX9Jy-ytdHpCIY85Vi4mr2rHI4VC9yeVxJ1eV5ynsAYLYe94sqNKtwzVuYkcgCuAbaXxHqNxHZsBU-cgaA/file# [following]
# --2022-10-13 17:43:00--  https://ucd3dada479b364e64135989358a.dl.dropboxusercontent.com/cd/0/inline/BuzfYkLFm6ehKK6rmKt2mqApbkICJZKTVM1sUktzv-PHYTpPyNXHmPo3CbpOHI-QROu90sGHiZHYZM3X7fhb510XKLJUWX9Jy-ytdHpCIY85Vi4mr2rHI4VC9yeVxJ1eV5ynsAYLYe94sqNKtwzVuYkcgCuAbaXxHqNxHZsBU-cgaA/file
# Resolving ucd3dada479b364e64135989358a.dl.dropboxusercontent.com (ucd3dada479b364e64135989358a.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6021:15::a27d:410f
# Connecting to ucd3dada479b364e64135989358a.dl.dropboxusercontent.com (ucd3dada479b364e64135989358a.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 347117594 (331M) [text/plain]
# Saving to: ‘glove.6B.100d.txt’
#
# glove.6B.100d.txt   100%[===================>] 331.04M  45.2MB/s    in 7.6s
#
# 2022-10-13 17:43:09 (43.5 MB/s) - ‘glove.6B.100d.txt’ saved [347117594/347117594]

# %%
path = './yelp.csv'
yelp = pd.read_csv(path)
# Create a new DataFrame that only contains the 5-star and 1-star reviews.
yelp_best_worst = yelp[(yelp.stars==5) | (yelp.stars==1)]
X = yelp_best_worst.text
y = yelp_best_worst.stars.map({1:0, 5:1})

# %%
corpus = [sentence for sentence in X.values if type(sentence) == str and len(TextBlob(sentence).words) > 3]

# %%
path_to_glove_file = "./glove.6B.100d.txt"
embeddings_index = {}
with open(path_to_glove_file) as f:
    for line in f:
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, "f", sep=" ")
        embeddings_index[word] = coefs

print("Found %s word vectors." % len(embeddings_index))
# Out:
# Found 400001 word vectors.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
tokenized_corpus = tokenizer.texts_to_sequences(corpus)
nb_samples = sum(len(s) for s in corpus)
vocab_size = len(tokenizer.word_index) + 1

# %%
print(f'First 5 corpus items are {corpus[:5]}')
print(f'Length of corpus is {len(corpus)}')
# Out:
# First 5 corpus items are ['My wife took me here on my birthday for breakfast and it was excellent.  The weather was perfect which made sitting outside overlooking their grounds an absolute pleasure.  Our waitress was excellent and our food arrived quickly on the semi-busy Saturday morning.  It looked like the place fills up pretty quickly so the earlier you get here the better.\n\nDo yourself a favor and get their Bloody Mary.  It was phenomenal and simply the best I\'ve ever had.  I\'m pretty sure they only use ingredients from their garden and blend them fresh when you order it.  It was amazing.\n\nWhile EVERYTHING on the menu looks excellent, I had the white truffle scrambled eggs vegetable skillet and it was tasty and delicious.  It came with 2 pieces of their griddled bread with was amazing and it absolutely made the meal complete.  It was the best "toast" I\'ve ever had.\n\nAnyway, I can\'t wait to go back!', 'I have no idea why some people give bad reviews about this place. It goes to show you, you can please everyone. They are probably griping about something that their own fault...there are many people like that.\n\nIn any case, my friend and I arrived at about 5:50 PM this past Sunday. It was pretty crowded, more than I thought for a Sunday evening and thought we would have to wait forever to get a seat but they said we\'ll be seated when the girl comes back from seating someone else. We were seated at 5:52 and the waiter came and got our drink orders. Everyone was very pleasant from the host that seated us to the waiter to the server. The prices were very good as well. We placed our orders once we decided what we wanted at 6:02. We shared the baked spaghetti calzone and the small "Here\'s The Beef" pizza so we can both try them. The calzone was huge and we got the smallest one (personal) and got the small 11" pizza. Both were awesome! My friend liked the pizza better and I liked the calzone better. The calzone does have a sweetish sauce but that\'s how I like my sauce!\n\nWe had to box part of the pizza to take it home and we were out the door by 6:42. So, everything was great and not like these bad reviewers. That goes to show you that  you have to try these things yourself because all these bad reviewers have some serious issues.', "Rosie, Dakota, and I LOVE Chaparral Dog Park!!! It's very convenient and surrounded by a lot of paths, a desert xeriscape, baseball fields, ballparks, and a lake with ducks.\n\nThe Scottsdale Park and Rec Dept. does a wonderful job of keeping the park clean and shaded.  You can find trash cans and poopy-pick up mitts located all over the park and paths.\n\nThe fenced in area is huge to let the dogs run, play, and sniff!", 'General Manager Scott Petello is a good egg!!! Not to go into detail, but let me assure you if you have any issues (albeit rare) speak with Scott and treat the guy with some respect as you state your case and I\'d be surprised if you don\'t walk out totally satisfied as I just did. Like I always say..... "Mistakes are inevitable, it\'s how we recover from them that is important"!!!\n\nThanks to Scott and his awesome staff. You\'ve got a customer for life!! .......... :^)', 'Drop what you\'re doing and drive here. After I ate here I had to go back the next day for more.  The food is that good.\n\nThis cute little green building may have gone competely unoticed if I hadn\'t been driving down Palm Rd to avoid construction.  While waiting to turn onto 16th Street the "Grand Opening" sign caught my eye and my little yelping soul leaped for joy!  A new place to try!\n\nIt looked desolate from the outside but when I opened the door I was put at easy by the decor, smell and cleanliness inside.  I ordered dinner for two, to go.  The menu was awesome.  I loved seeing all the variety: poblano peppers, mole, mahi mahi, mushrooms...something wrapped in banana leaves.  It made it difficult to choose something.  Here\'s what I\'ve had so far: La Condesa Shrimp Burro and Baja Sur Do ...
# Length of corpus is 4056

# %%
num_tokens = vocab_size + 1
hits = 0
misses = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((num_tokens, embedding_dim))
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # Words not found in embedding index will be all-zeros.
        # This includes the representation for "padding" and "OOV"
        embedding_matrix[i] = embedding_vector
        hits += 1
    else:
        misses += 1
print("Converted %d words (%d misses)" % (hits, misses))
# Out:
# Converted 17190 words (2759 misses)

# %%
model = Sequential()
model.add(Embedding(input_dim=num_tokens, output_dim=embedding_dim, input_length=4, embeddings_initializer=Constant(embedding_matrix),
    trainable=False))
model.add(Lambda(lambda x: K.mean(x, axis=1), output_shape=(embedding_dim,)))
model.add(Dense(vocab_size, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 4, 100)            1995100
#
#  lambda (Lambda)             (None, 100)               0
#
#  dense (Dense)               (None, 19950)             2014950
#
# =================================================================
# Total params: 4,010,050
# Trainable params: 2,014,950
# Non-trainable params: 1,995,100
# _________________________________________________________________

# %%
def generate_data(corpus, vocab_size, window_size=2, sentence_batch_size=10,  batch_size=250):
    np.random.shuffle(np.array(corpus))
    number_of_sentence_batches = (len(corpus) // sentence_batch_size) + 1
    for batch in range(number_of_sentence_batches):
        lower_end = batch*batch_size
        upper_end = (batch+1)*batch_size if batch+1 < number_of_sentence_batches else len(corpus)
        mini_batch_size = upper_end - lower_end
        maxlen = window_size*2
        X = []
        Y = []
        for review_id, words in enumerate(corpus[lower_end:upper_end]):
            L = len(words)
            for index, word in enumerate(words):
                contexts = []
                labels   = []            
                s = index - window_size
                e = index + window_size + 1

                contexts.append([words[i] for i in range(s, e) if 0 <= i < L and i != index])
                labels.append(word)

                x = pad_sequences(contexts, maxlen=maxlen)
                y = np_utils.to_categorical(labels, vocab_size)
                X.append(x)
                Y.append(y)
        X = tf.constant(X)
        Y = tf.constant(Y)
        number_of_batches = len(X) // batch_size
        for real_batch in range(number_of_batches):
          lower_end = batch*batch_size
          upper_end = (batch+1)*batch_size
          batch_X = tf.squeeze(X[lower_end:upper_end])
          batch_Y = tf.squeeze(Y[lower_end:upper_end])
          yield (batch_X, batch_Y)

# %%
def fit_model():
    if not BATCH:
        X, Y = generate_data(corpus=tokenized_corpus, vocab_size=vocab_size, batch_size=len(X))
        print(f'Size of X is {X.shape} and Y is {Y.shape}')
        model.fit(X, Y, epochs = epochs)
    else:
        for epoch in range(epochs):
          index = 1
          for x, y in generate_data(corpus=tokenized_corpus, vocab_size=vocab_size, batch_size=batch_size):
              print(f'Training on Epoch/Iteration: {epoch+1}/{index}')
              index += 1
              history = model.train_on_batch(x, y, reset_metrics=False, return_dict=True)
              print(history)

# %%
fit_model()
# Out:
# Training on Epoch/Iteration: 1/1
# {'loss': 9.899017333984375}
# Training on Epoch/Iteration: 1/2
# {'loss': 9.874351501464844}
# Training on Epoch/Iteration: 1/3
# {'loss': 9.849365234375}
# Training on Epoch/Iteration: 1/4
# {'loss': 9.82418441772461}
# Training on Epoch/Iteration: 1/5
# {'loss': 9.798870086669922}
# Training on Epoch/Iteration: 1/6
# {'loss': 9.773459434509277}
# Training on Epoch/Iteration: 1/7
# {'loss': 9.74797534942627}
# Training on Epoch/Iteration: 1/8
# {'loss': 9.722434043884277}
# Training on Epoch/Iteration: 1/9
# {'loss': 9.696846008300781}
# Training on Epoch/Iteration: 1/10
# {'loss': 9.671223640441895}
# Training on Epoch/Iteration: 1/11
# {'loss': 9.645570755004883}
# Training on Epoch/Iteration: 1/12
# {'loss': 9.619895935058594}
# Training on Epoch/Iteration: 1/13
# {'loss': 9.594202995300293}
# Training on Epoch/Iteration: 1/14
# {'loss': 9.568495750427246}
# Training on Epoch/Iteration: 1/15
# {'loss': 9.542778968811035}
# Training on Epoch/Iteration: 1/16
# {'loss': 9.51705551147461}
# Training on Epoch/Iteration: 1/17
# {'loss': 9.491329193115234}
# Training on Epoch/Iteration: 1/18
# {'loss': 9.465600967407227}
# Training on Epoch/Iteration: 1/19
# {'loss': 9.439874649047852}
# Training on Epoch/Iteration: 1/20
# {'loss': 9.414151191711426}
# Training on Epoch/Iteration: 1/21
# {'loss': 9.388436317443848}
# Training on Epoch/Iteration: 1/22
# {'loss': 9.3627290725708}
# Training on Epoch/Iteration: 1/23
# {'loss': 9.337032318115234}
# Training on Epoch/Iteration: 1/24
# {'loss': 9.311347961425781}
# Training on Epoch/Iteration: 1/25
# {'loss': 9.285677909851074}
# Training on Epoch/Iteration: 1/26
# {'loss': 9.260024070739746}
# Training on Epoch/Iteration: 1/27
# {'loss': 9.234389305114746}
# Training on Epoch/Iteration: 1/28
# {'loss': 9.208773612976074}
# Training on Epoch/Iteration: 1/29
# {'loss': 9.183180809020996}
# Training on Epoch/Iteration: 1/30
# {'loss': 9.157612800598145}
# Training on Epoch/Iteration: 1/31
# {'loss': 9.13206958770752}
# Training on Epoch/Iteration: 1/32
# {'loss': 9.106554985046387}
# Training on Epoch/Iteration: 1/33
# {'loss': 9.081068992614746}
# Training on Epoch/Iteration: 1/34
# {'loss': 9.055614471435547}
# Training on Epoch/Iteration: 1/35
# {'loss': 9.030194282531738}
# Training on Epoch/Iteration: 1/36
# {'loss': 9.004809379577637}
# Training on Epoch/Iteration: 1/37
# {'loss': 8.979460716247559}
# Training on Epoch/Iteration: 1/38
# {'loss': 8.954153060913086}
# Training on Epoch/Iteration: 1/39
# {'loss': 8.928885459899902}
# Training on Epoch/Iteration: 1/40
# {'loss': 8.903661727905273}
# Training on Epoch/Iteration: 1/41
# {'loss': 8.878482818603516}
# Training on Epoch/Iteration: 1/42
# {'loss': 8.853352546691895}
# Training on Epoch/Iteration: 1/43
# {'loss': 8.828271865844727}
# Training on Epoch/Iteration: 1/44
# {'loss': 8.803242683410645}
# Training on Epoch/Iteration: 1/45
# {'loss': 8.778267860412598}
# Training on Epoch/Iteration: 1/46
# {'loss': 8.753349304199219}
# Training on Epoch/Iteration: 1/47
# {'loss': 8.72848892211914}
# Training on Epoch/Iteration: 1/48
# {'loss': 8.703688621520996}
# Training on Epoch/Iteration: 1/49
# {'loss': 8.67895221710205}
# Training on Epoch/Iteration: 1/50
# {'loss': 8.654280662536621}
# Training on Epoch/Iteration: 1/51
# {'loss': 8.629676818847656}
# Training on Epoch/Iteration: 1/52
# {'loss': 8.605142593383789}
# Training on Epoch/Iteration: 1/53
# {'loss': 8.580680847167969}
# Training on Epoch/Iteration: 1/54
# {'loss': 8.556292533874512}
# Training on Epoch/Iteration: 1/55
# {'loss': 8.531981468200684}
# Training on Epoch/Iteration: 1/56
# {'loss': 8.507749557495117}
# Training on Epoch/Iteration: 1/57
# {'loss': 8.483599662780762}
# Training on Epoch/Iteration: 1/58
# {'loss': 8.459532737731934}
# Training on Epoch/Iteration: 1/59
# {'loss': 8.435550689697266}
# Training on Epoch/Iteration: 1/60
# {'loss': 8.41165828704834}
# Training on Epoch/Iteration: 1/61
# {'loss': 8.38785457611084}
# Training on Epoch/Iteration: 1/62
# {'loss': 8.364144325256348}
# Training on Epoch/Iteration: 1/63
# {'loss': 8.34052848815918}
# Training on Epoch/Iteration: 1/64
# {'loss': 8.317009925842285}
# Training on Epoch/Iteration: 1/65
# {'loss': 8.29358959197998}
# Training on Epoch/Iteration: 1/66
# {'loss': 8.270270347595215}
# Training on Epoch/Iteration: 1/67
# {'loss': 8.247053146362305}
# Training on Epoch/Iteration: 1/68
# {'loss': 8.2239408493042}
# Training on Epoch/Iteration: 1/69
# {'loss': 8.200935363769531}
# Training on Epoch/Iteration: 1/70
# {'loss': 8.178038597106934}
# Training on Epoch/Iteration: 1/71
# {'loss': 8.155251502990723}
# Training on Epoch/Iteration: 1/72
# {'loss': 8.132575988769531}
# Training on Epoch/Iteration: 1/73
# {'loss': 8.110014915466309}
# Training on Epoch/Iteration: 1/74
# {'loss': 8.087567329406738}
# Training on Epoch/Iteration: 1/75
# {'loss': 8.065237045288086}
# Training on Epoch/Iteration: 1/76
# {'loss': 8.043024063110352}
# Training on Epoch/Iteration: 1/77
# {'loss': 8.020929336547852}
# Training on Epoch/Iteration: 1/78
# {'loss': 7.998955249786377}
# Training on Epoch/Iteration: 1/79
# {'loss': 7.977102279663086}
# Training on Epoch/Iteration: 1/80
# {'loss': 7.955370903015137}
# Training on Epoch/Iteration: 1/81
# {'loss': 7.933763027191162}
# Training on Epoch/Iteration: 1/82
# {'loss': 7.91227912902832}
# Training on Epoch/Iteration: 1/83
# {'loss': 7.890919208526611}
# Training on Epoch/Iteration: 1/84
# {'loss': 7.869686126708984}
# Training on Epoch/Iteration: 1/85
# {'loss': 7.848577976226807}
# Training on Epoch/Iteration: 1/86
# {'loss': 7.827596664428711}
# Training on Epoch/Iteration: 1/87
# {'loss': 7.806742191314697}
# Training on Epoch/Iteration: 1/88
# {'loss': 7.786015510559082}
# Training on Epoch/Iteration: 1/89
# {'loss': 7.765416622161865}
# Training on Epoch/Iteration: 1/90
# {'loss': 7.744945049285889}
# Training on Epoch/Iteration: 1/91
# {'loss': 7.724601745605469}
# Training on Epoch/Iteration: 1/92
# {'loss': 7.7043867111206055}
# Training on Epoch/Iteration: 1/93
# {'loss': 7.684299945831299}
# Training on Epoch/Iteration: 1/94
# {'loss': 7.664340972900391}
# Training on Epoch/Iteration: 1/95
# {'loss': 7.644510746002197}
# Training on Epoch/Iteration: 1/96
# {'loss': 7.624807357788086}
# Training on Epoch/Iteration: 1/97
# {'loss': 7.605231761932373}
# Training on Epoch/Iteration: 1/98
# {'loss': 7.585783958435059}
# Training on Epoch/Iteration: 1/99
# {'loss': 7.566462516784668}
# Training on Epoch/Iteration: 1/100
# {'loss': 7.547267913818359}
# Training on Epoch/Iteration: 1/101
# {'loss': 7.528199672698975}
# Training on Epoch/Iteration: 1/102
# {'loss': 7.5092573165893555}
# Training on Epoch/Iteration: 1/103
# {'loss': 7.4904398918151855}
# Training on Epoch/Iteration: 1/104
# {'loss': 7.471747398376465}
# Training on Epoch/Iteration: 1/105
# {'loss': 7.453179359436035}
# Training on Epoch/Iteration: 1/106
# {'loss': 7.43473482131958}
# Training on Epoch/Iteration: 1/107
# {'loss': 7.416412830352783}
# Training on Epoch/Iteration: 1/108
# {'loss': 7.3982133865356445}
# Training on Epoch/Iteration: 1/109
# {'loss': 7.380135536193848}
# Training on Epoch/Iteration: 1/110
# {'loss': 7.362177848815918}
# Training on Epoch/Iteration: 1/111
# {'loss': 7.344340801239014}
# Training on Epoch/Iteration: 1/112
# {'loss': 7.32662296295166}
# Training on Epoch/Iteration: 1/113
# {'loss': 7.309023380279541}
# Training on Epoch/Iteration: 1/114
# {'loss': 7.291541576385498}
# Training on Epoch/Iteration: 1/115
# {'loss': 7.274177074432373}
# Training on Epoch/Iteration: 1/116
# {'loss': 7.256928443908691}
# Training on Epoch/Iteration: 1/117
# {'loss': 7.239794731140137}
# Training on Epoch/Iteration: 1/118
# {'loss': 7.222775936126709}
# Training on Epoch/Iteration: 1/119
# {'loss': 7.205870151519775}
# Training on Epoch/Iteration: 1/120
# {'loss': 7.189077377319336}
# Training on Epoch/Iteration: 1/121
# {'loss': 7.172396659851074}
# Training on Epoch/Iteration: 1/122
# {'loss': 7.155826568603516}
# Training on Epoch/Iteration: 1/123
# {'loss': 7.139366149902344}
# Training on Epoch/Iteration: 1/124
# {'loss': 7.146353721618652}
# Training on Epoch/Iteration: 1/125
# {'loss': 7.153031349182129}
# Training on Epoch/Iteration: 1/126
# {'loss': 7.159343242645264}
# Training on Epoch/Iteration: 1/127
# {'loss': 7.165254592895508}
# Training on Epoch/Iteration: 1/128
# {'loss': 7.170741558074951}
# Training on Epoch/Iteration: 1/129
# {'loss': 7.175790309906006}
# Training on Epoch/Iteration: 1/130
# {'loss': 7.18039083480835}
# Training on Epoch/Iteration: 1/131
# {'loss': 7.184539794921875}
# Training on Epoch/Iteration: 1/132
# {'loss': 7.188236236572266}
# Training on Epoch/Iteration: 1/133
# {'loss': 7.1914825439453125}
# Training on Epoch/Iteration: 1/134
# {'loss': 7.194283485412598}
# Training on Epoch/Iteration: 1/135
# {'loss': 7.196645736694336}
# Training on Epoch/Iteration: 1/136
# {'loss': 7.198577404022217}
# Training on Epoch/Iteration: 1/137
# {'loss': 7.200087070465088}
# Training on Epoch/Iteration: 1/138
# {'loss': 7.201185703277588}
# Training on Epoch/Iteration: 1/139
# {'loss': 7.201883316040039}
# Training on Epoch/Iteration: 1/140
# {'loss': 7.2021918296813965}
# Training on Epoch/Iteration: 1/141
# {'loss': 7.202122688293457}
# Training on Epoch/Iteration: 1/142
# {'loss': 7.201687335968018}
# Training on Epoch/Iteration: 1/143
# {'loss': 7.20089864730835}
# Training on Epoch/Iteration: 1/144
# {'loss': 7.199767589569092}
# Training on Epoch/Iteration: 1/145
# {'loss': 7.198307037353516}
# Training on Epoch/Iteration: 1/146
# {'loss': 7.196528434753418}
# Training on Epoch/Iteration: 1/147
# {'loss': 7.194443225860596}
# Training on Epoch/Iteration: 1/148
# {'loss': 7.192063331604004}
# Training on Epoch/Iteration: 1/149
# {'loss': 7.1894001960754395}
# Training on Epoch/Iteration: 1/150
# {'loss': 7.186464786529541}
# Training on Epoch/Iteration: 1/151
# {'loss': 7.183267593383789}
# Training on Epoch/Iteration: 1/152
# {'loss': 7.179818153381348}
# Training on Epoch/Iteration: 1/153
# {'loss': 7.1761274337768555}
# Training on Epoch/Iteration: 1/154
# {'loss': 7.172205448150635}
# Training on Epoch/Iteration: 1/155
# {'loss': 7.168060302734375}
# Training on Epoch/Iteration: 1/156
# {'loss': 7.163702011108398}
# Training on Epoch/Iteration: 1/157
# {'loss': 7.1591386795043945}
# Training on Epoch/Iteration: 1/158
# {'loss': 7.1543779373168945}
# Training on Epoch/Iteration: 1/159
# {'loss': 7.149428367614746}
# Training on Epoch/Iteration: 1/160
# {'loss': 7.1442975997924805}
# Training on Epoch/Iteration: 1/161
# {'loss': 7.1389923095703125}
# Training on Epoch/Iteration: 1/162
# {'loss': 7.133519172668457}
# Training on Epoch/Iteration: 1/163
# {'loss': 7.127885818481445}
# Training on Epoch/Iteration: 1/164
# {'loss': 7.122097492218018}
# Training on Epoch/Iteration: 1/165
# {'loss': 7.116161346435547}
# Training on Epoch/Iteration: 1/166
# {'loss': 7.110082149505615}
# Training on Epoch/Iteration: 1/167
# {'loss': 7.103866100311279}
# Training on Epoch/Iteration: 1/168
# {'loss': 7.097517967224121}
# Training on Epoch/Iteration: 1/169
# {'loss': 7.091042995452881}
# Training on Epoch/Iteration: 1/170
# {'loss': 7.084446430206299}
# Training on Epoch/Iteration: 1/171
# {'loss': 7.077732563018799}
# Training on Epoch/Iteration: 1/172
# {'loss': 7.070905685424805}
# Training on Epoch/Iteration: 1/173
# {'loss': 7.063970565795898}
# Training on Epoch/Iteration: 1/174
# {'loss': 7.056931018829346}
# Training on Epoch/Iteration: 1/175
# {'loss': 7.04979133605957}
# Training on Epoch/Iteration: 1/176
# {'loss': 7.042555332183838}
# Training on Epoch/Iteration: 1/177
# {'loss': 7.035225868225098}
# Training on Epoch/Iteration: 1/178
# {'loss': 7.027807712554932}
# Training on Epoch/Iteration: 1/179
# {'loss': 7.020303249359131}
# Training on Epoch/Iteration: 1/180
# {'loss': 7.012715816497803}
# Training on Epoch/Iteration: 1/181
# {'loss': 7.005049705505371}
# Training on Epoch/Iteration: 1/182
# {'loss': 6.997307777404785}
# Training on Epoch/Iteration: 1/183
# {'loss': 6.989492416381836}
# Training on Epoch/Iteration: 1/184
# {'loss': 6.981606483459473}
# Training on Epoch/Iteration: 1/185
# {'loss': 6.973653316497803}
# Training on Epoch/Iteration: 1/186
# {'loss': 6.965635776519775}
# Training on Epoch/Iteration: 1/187
# {'loss': 6.957556247711182}
# Training on Epoch/Iteration: 1/188
# {'loss': 6.949417591094971}
# Training on Epoch/Iteration: 1/189
# {'loss': 6.941222190856934}
# Training on Epoch/Iteration: 1/190
# {'loss': 6.932972431182861}
# Training on Epoch/Iteration: 1/191
# {'loss': 6.924670696258545}
# Training on Epoch/Iteration: 1/192
# {'loss': 6.916319847106934}
# Training on Epoch/Iteration: 1/193
# {'loss': 6.90792179107666}
# Training on Epoch/Iteration: 1/194
# {'loss': 6.899478912353516}
# Training on Epoch/Iteration: 1/195
# {'loss': 6.890993118286133}
# Training on Epoch/Iteration: 1/196
# {'loss': 6.882466793060303}
# Training on Epoch/Iteration: 1/197
# {'loss': 6.873902320861816}
# Training on Epoch/Iteration: 1/198
# {'loss': 6.865301609039307}
# Training on Epoch/Iteration: 1/199
# {'loss': 6.856666564941406}
# Training on Epoch/Iteration: 1/200
# {'loss': 6.84799861907959}
# Training on Epoch/Iteration: 1/201
# {'loss': 6.839301109313965}
# Training on Epoch/Iteration: 1/202
# {'loss': 6.830574035644531}
# Training on Epoch/Iteration: 1/203
# {'loss': 6.8218207359313965}
# Training on Epoch/Iteration: 1/204
# {'loss': 6.813042163848877}
# Training on Epoch/Iteration: 1/205
# {'loss': 6.804240703582764}
# Training on Epoch/Iteration: 1/206
# {'loss': 6.795417308807373}
# Training on Epoch/Iteration: 1/207
# {'loss': 6.786574363708496}
# Training on Epoch/Iteration: 1/208
# {'loss': 6.777712821960449}
# Training on Epoch/Iteration: 1/209
# {'loss': 6.768835067749023}
# Training on Epoch/Iteration: 1/210
# {'loss': 6.759941577911377}
# Training on Epoch/Iteration: 1/211
# {'loss': 6.751034736633301}
# Training on Epoch/Iteration: 1/212
# {'loss': 6.742115497589111}
# Training on Epoch/Iteration: 1/213
# {'loss': 6.733185291290283}
# Training on Epoch/Iteration: 1/214
# {'loss': 6.724246025085449}
# Training on Epoch/Iteration: 1/215
# {'loss': 6.715298175811768}
# Training on Epoch/Iteration: 1/216
# {'loss': 6.706343650817871}
# Training on Epoch/Iteration: 1/217
# {'loss': 6.697383403778076}
# Training on Epoch/Iteration: 1/218
# {'loss': 6.688419342041016}
# Training on Epoch/Iteration: 1/219
# {'loss': 6.6794514656066895}
# Training on Epoch/Iteration: 1/220
# {'loss': 6.6704816818237305}
# Training on Epoch/Iteration: 1/221
# {'loss': 6.661510944366455}
# Training on Epoch/Iteration: 1/222
# {'loss': 6.65254020690918}
# Training on Epoch/Iteration: 1/223
# {'loss': 6.6435699462890625}
# Training on Epoch/Iteration: 1/224
# {'loss': 6.6346025466918945}
# Training on Epoch/Iteration: 1/225
# {'loss': 6.625638484954834}
# Training on Epoch/Iteration: 1/226
# {'loss': 6.616677761077881}
# Training on Epoch/Iteration: 1/227
# {'loss': 6.60772180557251}
# Training on Epoch/Iteration: 1/228
# {'loss': 6.598772048950195}
# Training on Epoch/Iteration: 1/229
# {'loss': 6.5898284912109375}
# Training on Epoch/Iteration: 1/230
# {'loss': 6.580892562866211}
# Training on Epoch/Iteration: 1/231
# {'loss': 6.571964263916016}
# Training on Epoch/Iteration: 1/232
# {'loss': 6.563044548034668}
# Training on Epoch/Iteration: 1/233
# {'loss': 6.554134845733643}
# Training on Epoch/Iteration: 1/234
# {'loss': 6.5452351570129395}
# Training on Epoch/Iteration: 1/235
# {'loss': 6.536345958709717}
# Training on Epoch/Iteration: 1/236
# {'loss': 6.527468204498291}
